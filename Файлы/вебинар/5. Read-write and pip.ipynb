# %% [markdown]
# ### Задача с собеседований
#
# Дана строчка sequence с последовательностью натуральных чисел, разделенных пробелом. Посчитайте:
# 1. Количество четных и нечетных чисел в этой строке
# 2. Если четных больше, то укажите номер позиции первого "лишнего" нечетного числа
# 3. Если нечетных больше, то укажите позицию первого "лишнего" четного числа
# 4. Как бонусный вариант оформите код в виде функции

# %%
sequence = '2 3 1 5 9 22 3 5'

# %%
'---2 3 1 5 9 22 3 5\n---'.strip('-\n')
# Out:
# '2 3 1 5 9 22 3 5'

# %%
sequence.strip().split(' ')
# Out:
# ['2', '3', '1', '5', '9', '22', '3', '5']

# %%
for num in sequence.split():
    print(int(num), int(num) % 2)
# Out:
# 2 0
# 3 1
# 1 1
# 5 1
# 9 1
# 22 0
# 3 1
# 5 1

# %%
ev_count = 0  # even
odd_count = 0   # odd

for num in sequence.split(): 
    if int(num) % 2 == 0: 
        ev_count += 1   # ev_count = ev_count + 1
    else: 
        odd_count += 1 
        
print(ev_count) 
print(odd_count)
# Out:
# 2
# 6

# %%
ev_count = 0 
odd_count = 0 

for num in sequence.split(): 
    if int(num) % 2 == 0: 
        ev_count +=1 
    else: 
        odd_count += 1 
        
if ev_count > odd_count: 
    for i, num in enumerate(sequence.split()): 
        if int(num) % 2 != 0: 
            print(f'Позиция первого нечетного числа {i}') 
            break 
else:    
    for i, num in enumerate(sequence.split()): 
        if int(num) % 2 == 0: 
            print(f'Позиция первого четного числа: {i}') 
            break
# Out:
# Позиция первого четного числа: 0

# %%
even_list = [int(x) for x in sequence.split() if int(x) % 2 == 0]
even_list
# Out:
# [2, 22]

# %%
odd_list = [int(x) for x in sequence.split() if int(x) % 2 != 0]
odd_list
# Out:
# [3, 1, 5, 9, 3, 5]

# %%
odd_list.index(9)
# Out:
# 3

# %%
if len(odd_list) > len(even_list):
    print(even_list[0], sequence.split().index(str(even_list[0])))
# Out:
# 2 0

# %% [markdown]
# # Чтение файлов
# Рассматриваем задачу сквозной аналитики. Будем работать с этими файлами:
# - visit_log.csv
# - purchase_log.txt

# %% [markdown]
# ### Способ 1. Делаем все пошагово
# Опции при открытии файлов:
# - 'r' открыть для чтения. Файл при этом не меняется
# - 'w' открыть файл для записи. Файл при этом полностью чистится (!)
# - 'a' открыть файл для добавления. Файл не меняется, все записи добавляются в конец

# %%
# открываем файл для чтения (опция r)
f = open('visit_log.csv', 'r')

# %%
# прочитать первую строчку
f.readline()
# Out:
# 'user_id,source\n'

# %%
for line in f:
    print(line)
    break
# Out:
# 6450655ae8,other

# %%
# прочитать еще одну
f.readline()
# Out:
# '6450655ae8,other\n'

# %%
# можно и так
next(f)
# Out:
# 'b4ea53e670,other\n'

# %%
StringIO

# %%
yield

# %%
f.seek(0)  # номер буквы

# %%
# прочитать все содержимое файла в переменную content
content = f.readlines()

# %%
content[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c97b90c97eef> in <module>
# ----> 1 content[:5]
#
# NameError: name 'content' is not defined

# %% [markdown]
# # Garbage collector

# %%
content = []

# %%
f = open('/Users/kbashevoy/Desktop/Нетология/Занятия/Занятие 5/data/file_1.csv')

# %%
'каждый охотник \'желает\' \
знать'
# Out:
# "каждый охотник 'желает' знать"

# %%
'select * from db.table where date=\'2020-10-23\''
# Out:
# "select * from db.table where date='2020-10-23'"

# %%
'C:\\Users\\kbashevoy\\data\\file.csv'
# Out:
# 'C:\\Users\\kbashevoy\\data\\file.csv'

# %%
f = open('C:\\Users\\kbashevoy\\data\\file.csv')

# %%
f = open(r'C:\Users\kbashevoy\data\file.csv')

# %%
# построчное чтение файла
for line in f:
    print(line)
    
    break
# Out:
# b4ea53e670,other

# %%
import json

# %%
with open('purchase_log.txt', encoding='utf-8') as f:
    f.readline()
    
    for line in f: 
        line = line.strip() 
        dict_ = json.loads(line) 
        
        print(dict_["user_id"], ':', dict_["category"])
# Out:
# user_id : category
# 1840e0b9d4 : Продукты
# 4e4f90fcfb : Электроника
# afea8d72fc : Электроника
# 373a6055fe : Бытовая техника
# 9b2ab046f3 : Электроника
# 9f39d307c3 : Электроника
# 44edeffc91 : Продукты
# 704474fa2d : Продукты
# 1de31be403 : Бытовая техника
# b71f36a5e4 : Продукты
# 79843a685a : Продукты
# ff68cee0d6 : Бытовая техника
# e8447c40e2 : Досуг
# 98d290be27 : Электроника
# fa0079a5a8 : Досуг
# 22d2f03a17 : Досуг
# 3f8e1ccd3f : Электроника
# 81a9988b83 : Электроника
# 65f44a2eb7 : Досуг
# 5f8fbb0149 : Бытовая техника
# 3ecff691fd : Электроника
# dd0e912251 : Электроника
# 9250593d55 : Электроника
# 37c4e090e4 : Электроника
# 22fa3ea76f : Электроника
# 73b876b237 : Электроника
# f983a69d67 : Товары для животных
# 4ea17212f8 : Продукты
# c6de96a5e2 : Товары для животных
# d8e3bcee53 : Продукты
# 680aa815f9 : Продукты
# 4a92a68cf9 : Электроника
# 905e60cb52 : Бытовая техника
# 393bcfb298 : Продукты
# 06d450cc57 : Электроника
# b60ce22f17 : Электроника
# ...

# %% [markdown]
# Часто используется конструкция
# ```python
# another_line.strip().split(',')
# ```

# %%
another_line = f.readline()
another_line

# %%
# удаляем перенос строки и лишние пробелы
another_line.strip()

# %%
# разбиваем столбцы
another_line.strip().split(',')

# %%
# закрытие файла
f.close()

# %%
# после закрытия не получится прочитать
f.readline()

# %%
# прочитать все строчки файла в список (т. е. в оперативную память)
f = open('visit_log.csv', 'r')

content = f.readlines()

f.close()

# %%
content[:5]

# %% [markdown]
# ### Упражнение
# Напишите функцию (или просто код), который возвращает список из первых N строк файла purchase_log.txt без записи всего содержимого файла в оперативную память.

# %% [markdown]
# # Запись в файл
# Зачем все-таки открывать и закрывать файлы?

# %%
f = open('results.csv', 'w')

# %%
f.write('Начинаю запись первой строки...\n')
# Out:
# 32

# %%
f.write('Начинаю запись второй строки...\n')
# Out:
# 32

# %% [markdown]
# Здесь кто-то еще хочет в него записать

# %%
my_friend_results = open('results.csv', 'w')

# %%
my_friend_results.write('Тут еще результаты есть')
# Out:
# 23

# %%
# пишем свой результат
f.close()

# %%
# и наш результат перезатирается
my_friend_results.close()

# %% [markdown]
# ### Контекстный менеджер
# Как обезопасить себя от подобных накладок

# %%
with open('results.csv', 'w') as f:
    with open('results.csv', 'w') as my_friend_results:
        f.write('Начинаю запись первой строки...\n')
        f.write('Начинаю запись второй строки...\n')

#         my_friend_results = open('results.csv', 'w')
        my_friend_results.write('Тут еще результаты есть')
#         my_friend_results.close()

# %% [markdown]
# ### А можно читать и сразу в файл записывать?
# Напишите функцию, которая фильтрует файл visit_log.csv по источнику context и пишет результат в visits_context.csv. Используйте функцию из второго упражнения для проверки результата.

# %% [markdown]
# # Чтение списков и словарей из файла
# Смотрим что в файле purchase_log.txt. Похоже тут не строки, а словари

# %%
with open('purchase_log.txt') as f:
    print([next(f) for x in range(5)])

# %%
import json

# %%
# перевод строки в словарь
dict_in_string = '{"a": 1, "b": 2}'

type(json.loads(dict_in_string))

# %%
# перевод строки в список
list_in_string = '[1, 2, 3]'

json.loads(list_in_string)[-1]

# %%
i = 0
with open('purchase_log.txt') as f:
    for line in f:
        line = line.strip()
        
        dict_ = json.loads(line)
        print(dict_, type(dict_))
        
        i += 1
        if i > 5:
            break

# %% [markdown]
# ### Из словаря в строку тоже можно

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
json.dumps(data)

# %%
type(json.dumps(data))

# %% [markdown]
# # Модуль pickle
# Запись объекта сразу в файл как поток байтов

# %% [markdown]
# # sklearn --> version

# %%
import pickle

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
with open('data.pickle', 'wb') as f:
    pickle.dump(data, f)

# %%
# прочитать объект из такого файла

with open('data.pickle', 'rb') as f:
    dict_ = pickle.load(f)
    
dict_, dict_['user_id']

# %% [markdown]
# # Чтение файлов из папки

# %%
import os

# %%
# чтение файлов и папок
for file in os.listdir('data'):
    print(file)

# %%
# чтение всех файлов и папок, в том числе вложенных
for root, directory, file in os.walk('data'):
    print(root, directory, file)

# %% [markdown]
# # Каталог пакетов pip (Python Package Index)
# Варианты установки
# 1. С помощью Anaconda Navigator
# 2. В командной строке (Terminal на маке)
# ```bash
# pip install package_name
# ```
# 3. Скачать версию с github и установить вручную
# ```bash
# pip install .
# ```
#
# Пакеты устанавливаются в определенное окружение! Вам пригодится virtualenv

# %%
# !pip install pyyaml

# %%
import plotly

# %% [markdown]
# # Простой импорт

# %%
import sys
sys.path

# %%
# добавляем в список библиотек папку libs
sys.path.append('libs')
sys.path

# %%
from useful_codes import CATEGORIES

# %%
CATEGORIES

# %%
from useful_codes import word_count

# %%
# посмотреть документацию функции

# ?word_count

# %%
word_count('Посчитай количество слов в тексте')

# %% [markdown]
# # Домашнее задание
# 1. Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# ```python
# {'1840e0b9d4': 'Продукты', ...}
# ```
#
# 2. Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия на данные:
# - содержимое purchase_log.txt помещается в оперативную память компьютера
# - содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %%
purchases = {'1840e0b9d4': 'Продукты', ...}

# %%
f2write = open('funnel.csv', 'w')

# %%
with open('funnel.csv') as f2write:
